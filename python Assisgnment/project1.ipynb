# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("Travel.csv")

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.dtypes
# Out:
# CustomerID                    int64
# ProdTaken                     int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# dtype: object

# %%
df.ProdTaken
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 4883    1
# 4884    1
# 4885    1
# 4886    1
# 4887    1
# Name: ProdTaken, Length: 4888, dtype: int64

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.Age
# Out:
# 0       41.0
# 1       49.0
# 2       37.0
# 3       33.0
# 4        NaN
#         ...
# 4883    49.0
# 4884    28.0
# 4885    52.0
# 4886    19.0
# 4887    36.0
# Name: Age, Length: 4888, dtype: float64

# %%
df.Age.describe()
# Out:
# count    4662.000000
# mean       37.622265
# std         9.316387
# min        18.000000
# 25%        31.000000
# 50%        36.000000
# 75%        44.000000
# max        61.000000
# Name: Age, dtype: float64

# %%
pd.crosstab(df.ProdTaken,df.Age)
# Out:
# Age        18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0  26.0  27.0  ...  \
# ProdTaken                                                              ...
# 0             6    11    13    18    31    33    38    54    69   108  ...
# 1             8    21    25    23    15    13    18    20    37    30  ...
#
# Age        52.0  53.0  54.0  55.0  56.0  57.0  58.0  59.0  60.0  61.0
# ProdTaken
# 0            54    58    59    57    46    24    20    32    28     9
# 1            14     8     2     7    12     5    11    12     1     0
#
# [2 rows x 44 columns]

# %%
d1=df['Age'].value_counts()

# %%
d1
# Out:
# 35.0    237
# 36.0    231
# 34.0    211
# 31.0    203
# 30.0    199
# 32.0    197
# 33.0    189
# 37.0    185
# 29.0    178
# 38.0    176
# 41.0    155
# 39.0    150
# 28.0    147
# 40.0    146
# 42.0    142
# 27.0    138
# 43.0    130
# 46.0    121
# 45.0    116
# 26.0    106
# 44.0    105
# 51.0     90
# 47.0     88
# 50.0     86
# 25.0     74
# 52.0     68
# 53.0     66
# 48.0     65
# 49.0     65
# 55.0     64
# 54.0     61
# 56.0     58
# 24.0     56
# 22.0     46
# 23.0     46
# 59.0     44
# 21.0     41
# 20.0     38
# 19.0     32
# 58.0     31
# 57.0     29
# 60.0     29
# 18.0     14
# 61.0      9
# Name: Age, dtype: int64

# %%
d1.sort_index()
# Out:
# 18.0     14
# 19.0     32
# 20.0     38
# 21.0     41
# 22.0     46
# 23.0     46
# 24.0     56
# 25.0     74
# 26.0    106
# 27.0    138
# 28.0    147
# 29.0    178
# 30.0    199
# 31.0    203
# 32.0    197
# 33.0    189
# 34.0    211
# 35.0    237
# 36.0    231
# 37.0    185
# 38.0    176
# 39.0    150
# 40.0    146
# 41.0    155
# 42.0    142
# 43.0    130
# 44.0    105
# 45.0    116
# 46.0    121
# 47.0     88
# 48.0     65
# 49.0     65
# 50.0     86
# 51.0     90
# 52.0     68
# 53.0     66
# 54.0     61
# 55.0     64
# 56.0     58
# 57.0     29
# 58.0     31
# 59.0     44
# 60.0     29
# 61.0      9
# Name: Age, dtype: int64

# %%
df2=pd.pivot_table(df,values="ProdTaken",index='Age',aggfunc=np.sum)

# %%
df2
# Out:
#       ProdTaken
# Age
# 18.0          8
# 19.0         21
# 20.0         25
# 21.0         23
# 22.0         15
# 23.0         13
# 24.0         18
# 25.0         20
# 26.0         37
# 27.0         30
# 28.0         26
# 29.0         57
# 30.0         48
# 31.0         41
# 32.0         40
# 33.0         40
# 34.0         44
# 35.0         34
# 36.0         27
# 37.0         24
# 38.0         15
# 39.0         14
# 40.0         23
# 41.0         24
# 42.0         20
# 43.0         10
# 44.0         17
# 45.0         18
# 46.0         11
# 47.0         12
# 48.0         11
# 49.0          9
# 50.0         12
# 51.0         17
# 52.0         14
# 53.0          8
# 54.0          2
# 55.0          7
# 56.0         12
# 57.0          5
# 58.0         11
# 59.0         12
# 60.0          1
# 61.0          0

# %%
contact_types=pd.pivot_table(df,values="ProdTaken",index='TypeofContact',aggfunc=np.sum)

# %%
contact_types
# Out:
#                  ProdTaken
# TypeofContact
# Company Invited        310
# Self Enquiry           607

# %%
correlation=pd.pivot_table(df,values="MonthlyIncome",index='CityTier',aggfunc=np.sum)

# %%
correlation
# Out:
#           MonthlyIncome
# CityTier
# 1            70839753.0
# 2             4564447.0
# 3            34546218.0

# %%
duration=pd.pivot_table(df,values="DurationOfPitch",index='ProdTaken',aggfunc=np.sum)

# %%
duration
# Out:
#            DurationOfPitch
# ProdTaken
# 0                  57067.0
# 1                  14764.0

# %%
occupdistri=df.groupby("Occupation")['CustomerID'].count()

# %%
occupdistri
# Out:
# Occupation
# Free Lancer          2
# Large Business     434
# Salaried          2368
# Small Business    2084
# Name: CustomerID, dtype: int64

# %%
occuppurchmean=df.groupby("Occupation")["ProdTaken"].mean()

# %%
occuppurchmean
# Out:
# Occupation
# Free Lancer       1.000000
# Large Business    0.276498
# Salaried          0.174831
# Small Business    0.184261
# Name: ProdTaken, dtype: float64

# %%
gen=pd.pivot_table(df,values="ProductPitched",index='Gender',aggfunc="count")

# %%
gen
# Out:
#          ProductPitched
# Gender
# Fe Male             155
# Female             1817
# Male               2916

# %%
tripwithprod=pd.pivot_table(df,values="ProdTaken",index='NumberOfTrips',aggfunc=np.sum)

# %%
tripwithprod
# Out:
#                ProdTaken
# NumberOfTrips
# 1.0                  112
# 2.0                  299
# 3.0                  217
# 4.0                   61
# 5.0                   62
# 6.0                   64
# 7.0                   62
# 8.0                   29
# 19.0                   1
# 20.0                   1
# 21.0                   0
# 22.0                   0

# %%
passport=df.groupby("Passport")["NumberOfTrips"].mean()

# %%
passport
# Out:
# Passport
# 0    3.221165
# 1    3.273844
# Name: NumberOfTrips, dtype: float64

# %%
likehood=df.groupby("Passport")["ProdTaken"].mean()

# %%
likehood
# Out:
# Passport
# 0    0.122908
# 1    0.347398
# Name: ProdTaken, dtype: float64

# %%
satisfactionofcustomers=df.groupby("PitchSatisfactionScore")["CustomerID"].count()

# %%
satisfactionofcustomers
# Out:
# PitchSatisfactionScore
# 1     942
# 2     586
# 3    1478
# 4     912
# 5     970
# Name: CustomerID, dtype: int64

# %%
checkingsatisfactionofcustomers = df.groupby("PitchSatisfactionScore")["ProdTaken"].sum()

# %%
checkingsatisfactionofcustomers
# Out:
# PitchSatisfactionScore
# 1    144
# 2     88
# 3    316
# 4    162
# 5    210
# Name: ProdTaken, dtype: int64

# %%
childrencount=df.groupby("NumberOfChildrenVisiting")["ProdTaken"].mean()

# %%
childrencount
# Out:
# NumberOfChildrenVisiting
# 0.0    0.186691
# 1.0    0.188462
# 2.0    0.189513
# 3.0    0.203077
# Name: ProdTaken, dtype: float64

# %%
genderprefer=pd.pivot_table(df,index='Gender',columns='ProductPitched',aggfunc='size',fill_value=0)

# %%
genderprefer
# Out:
# ProductPitched  Basic  Deluxe  King  Standard  Super Deluxe
# Gender
# Fe Male             4      83     0        63             5
# Female            676     641    82       263           155
# Male             1162    1008   148       416           182

# %%
effectofmarrige=pd.pivot_table(df,index='MaritalStatus',columns='ProductPitched',aggfunc='size',fill_value=0)

# %%
effectofmarrige
# Out:
# ProductPitched  Basic  Deluxe  King  Standard  Super Deluxe
# MaritalStatus
# Divorced          332     336    52       142            88
# Married           816     852   126       380           166
# Single            511     221    52        50            82
# Unmarried         183     323     0       170             6

# %%
maritalscore=df.groupby("MaritalStatus")["ProdTaken"].mean()

# %%
maritalscore
# Out:
# MaritalStatus
# Divorced     0.130526
# Married      0.139316
# Single       0.331878
# Unmarried    0.243402
# Name: ProdTaken, dtype: float64

# %%
meanofchildvisit=df.groupby("NumberOfChildrenVisiting")["ProdTaken"].mean()

# %%
meanofchildvisit
# Out:
# NumberOfChildrenVisiting
# 0.0    0.186691
# 1.0    0.188462
# 2.0    0.189513
# 3.0    0.203077
# Name: ProdTaken, dtype: float64

# %%
carownbtrips=df.groupby("OwnCar")["NumberOfTrips"].mean()

# %%
carownbtrips
# Out:
# OwnCar
# 0    3.264349
# 1    3.219346
# Name: NumberOfTrips, dtype: float64

# %%
owncarmean=df.groupby("OwnCar")["ProdTaken"].mean()

# %%
owncarmean
# Out:
# OwnCar
# 0    0.193966
# 1    0.184697
# Name: ProdTaken, dtype: float64

# %%
income=pd.pivot_table(df,index="MonthlyIncome",columns="ProductPitched",aggfunc='size',fill_value=0)

# %%
income
# Out:
# ProductPitched  Basic  Deluxe  King  Standard  Super Deluxe
# MonthlyIncome
# 1000.0              0       1     0         0             0
# 4678.0              0       1     0         0             0
# 16009.0             2       0     0         0             0
# 16051.0             2       0     0         0             0
# 16052.0             2       0     0         0             0
# ...               ...     ...   ...       ...           ...
# 38621.0             0       0     2         0             0
# 38651.0             0       0     2         0             0
# 38677.0             0       0     2         0             0
# 95000.0             1       0     0         0             0
# 98678.0             1       0     0         0             0
#
# [2475 rows x 5 columns]
